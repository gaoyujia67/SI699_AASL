# %% [markdown]
# # A Third-party Analysis of the *AASL Standards*
#
# Yujia Gao
#
# This section contains the analysis of the two stakeholders: **school librarians** and **state chapter organizations**. The goal for this split and our rationale for considering them seperately is that school librarians are the main user group of *the Standards* and the state chapter organizations are separate organizations that might guide their librarians.
#
# ## School Librarians
# #### Important Libraries

# %%
import pandas as pd

# %% [markdown]
# #### Load Data

# %%
df = pd.read_csv("School Librarians.csv")
df.shape
# Out:
# (791, 226)

# %% [markdown]
# #### Data Cleaning and Preprocessing
#
# Data cleaning was more complex than anticipated, primarily due to the survey's structure. Many questions allowed multiple selections or required respondents to rank choices, making the dataset format unconventional. Instead of a standard table with one row for field names and one column for record indexes, the dataset required reorganization. We expanded multi-choice responses into separate fields to facilitate analysis.
#
# Another challenge was the extensive demographic and work experience data collected. While the survey provided a comprehensive view of respondents, not all categories were necessary for our analysis. To maintain clarity, we categorized school librarians by **"Job Roles"** rather than alternative classifiers like school levels (elementary, middle, high school) or school settings (public, private, charter). This decision aligned with our client’s priorities, as they were particularly interested in insights from librarians with specific job titles.
#
# More specifically, we performed the following tasks:
# - **Dropped irrelevant fields.**
#     The dataset contained 52 questions, some of which overlapped in content or were not directly relevant to our analysis. To streamline the dataset, we removed redundant or unrelated fields, ensuring a clearer structure.
# - **Renamed columns.**
#     Since the dataset was directly exported from a survey platform, field names were lengthy question texts, making them difficult to reference in code. We assigned concise, descriptive names to improve readability and usability.
# - **Reformatted the dataset to handle multi-answer questions**
#     A major challenge was handling "select all that apply" questions, where respondents could choose multiple answers. The original data structure made analysis difficult, so we reorganized these responses into a more structured format. After renaming the columns, we also removed the first row, which contained subtitles rather than actual data, to ensure consistency.

# %%
df.head()
# Out:
#    Respondent ID  Collector ID           Start Date             End Date  \
# 0            NaN           NaN                  NaN                  NaN
# 1   1.144618e+11   428602709.0  2023-11-12 18:45:57  2023-11-29 08:28:25
# 2   1.144688e+11   428602709.0  2023-11-20 22:41:50  2023-11-20 22:44:30
# 3   1.144688e+11   428602709.0  2023-11-20 21:11:58  2023-11-20 21:20:02
# 4   1.144682e+11   428602709.0  2023-11-20 09:17:12  2023-11-20 19:20:08
#
#    IP Address  Email Address  First Name  Last Name  Custom Data 1  \
# 0         NaN            NaN         NaN        NaN            NaN
# 1         NaN            NaN         NaN        NaN            NaN
# 2         NaN            NaN         NaN        NaN            NaN
# 3         NaN            NaN         NaN        NaN            NaN
# 4         NaN            NaN         NaN        NaN            NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Respondent ID', 'Collector ID', 'Start Date', 'End Date', 'IP Address',
#        'Email Address', 'First Name', 'Last Name', 'Custom Data 1',
#        'Which of the following positions most closely reflects your job role? If you are retired, please select the option that is closest to the job role you had at retirement.',
#        ...
#        'Unnamed: 216',
#        'What is the primary language spoken in your work environment?',
#        'Unnamed: 218',
#        'Are you of Hispanic or Latino background – such as Mexican, Puerto Rican, Cuban, or another Latin American background?',
#        'Which of the following categories best describes your race or ethnicity?',
#        'Unnamed: 221',
#        'Which of the following categories best describes your employment status?',
#        'Unnamed: 223',
#        'Which of the following categories best describes your total household income last year, before taxes, including everyone in your household?',
# ...

# %%
# drop irrelavent ID and date fields
df = df.drop(columns=['Respondent ID', 'Collector ID', 
                                      'Start Date', 'End Date'])

# drop fields that contain only missing values (NaN)
df = df.dropna(axis=1, how='all')
df.head()
# Out:
#   Which of the following positions most closely reflects your job role? If you are retired, please select the option that is closest to the job role you had at retirement.  \
# 0                                           Response
# 1              Certified / licensed school librarian
# 2              Certified / licensed school librarian
# 3              Certified / licensed school librarian
# 4              Certified / licensed school librarian
#
#   Which of the following best describes your work environment? Please select all that apply. (i.e. If you are in a combined setting you may select multiple levels.)  \
# 0                                  Elementary school
# 1                                                NaN
# 2                                                NaN
# 3                                  Elementary school
# 4                                  Elementary school
#
#                            Unnamed: 11  Unnamed: 12         Unnamed: 13  \
# ...

# %% [markdown]
# Those "unnamed" columns are parts of the multiselect questions. They are choices under the mother question, so their actual "field names" are in the first row of this dataframe, which makes the dataframe odd-looking.

# %%
# drop Q2 and Q3
df = df.drop(df.columns[1:16], axis=1)

# drop Q7
df = df.drop(columns=['How valuable is your membership in AASL?'])

# %%
df.shape
# Out:
# (791, 201)

# %%
# drop Q37-Q49
df = df.drop(df.columns[174:200], axis=1)

# %%
for col in df.columns:
    print(col)
# Out:
# Which of the following positions most closely reflects your job role? If you are retired, please select the option that is closest to the job role you had at retirement.
# Which of the following groups or people are most influential in how you do your job? Please rank each, with “1” being the most influential and “8” being the least influential.
# Unnamed: 26
# Unnamed: 27
# Unnamed: 28
# Unnamed: 29
# Unnamed: 30
# Unnamed: 31
# Unnamed: 32
# Below is a list of organizations and associations that provide programs, standards, and guidelines. Please select the ones which are useful to you in your work as a school librarian. Please select all that apply.
# Unnamed: 34
# Unnamed: 35
# Unnamed: 36
# Unnamed: 37
# Unnamed: 38
# Unnamed: 39
# Unnamed: 40
# Unnamed: 41
# Unnamed: 42
# Unnamed: 43
# Unnamed: 44
# Unnamed: 45
# Unnamed: 46
# Unnamed: 47
# Unnamed: 48
# Unnamed: 49
# Unnamed: 50
# Are you a member of the American Association of School Librarians (AASL)?
# ...

# %%
df.shape
# Out:
# (791, 175)

# %%
df.head()
# Out:
#   Which of the following positions most closely reflects your job role? If you are retired, please select the option that is closest to the job role you had at retirement.  \
# 0                                           Response
# 1              Certified / licensed school librarian
# 2              Certified / licensed school librarian
# 3              Certified / licensed school librarian
# 4              Certified / licensed school librarian
#
#   Which of the following groups or people are most influential in how you do your job? Please rank each, with “1” being the most influential and “8” being the least influential.  \
# 0                                       School board
# 1                                                  6
# 2                                                  8
# 3                                                  7
# 4                                                  4
#
#             Unnamed: 26       Unnamed: 27  \
# ...

# %% [markdown]
# The above code prints all the left column names. After comparing one by one with the survey question, I confirmed manually that the left questions are what we want to analyze on and all the other unnecessary fields are dropped.
#
# The next step is to rename field names to make them shorted, as well as assigning all those "Unnamed" columns with something meaningful.

# %%
# Out:
#     How are you accessing the National School Library Standards? Please select all that apply.  \
# 0    I own a copy of the book publication National ...
# 1    I own a copy of the book publication National ...
# 2                                                  NaN
# 3    I own a copy of the book publication National ...
# 4                                                  NaN
# ..                                                 ...
# 786  I own a copy of the book publication National ...
# 787                                                NaN
# 788  I own a copy of the book publication National ...
# 789  I own a copy of the book publication National ...
# 790  I own a copy of the book publication National ...
#
#                                            Unnamed: 64  \
# 0    I borrow a copy of the National School Library...
# 1                                                  NaN
# 2                                                  NaN
# ...

# %%
df.rename(columns={df.columns[0]: 'jobRole',
                   
                   df.columns[1]: 'most_influential_school_board',
                   df.columns[2]: 'most_influential_school_administrator',
                   df.columns[3]: 'most_influential_school_principal',
                   df.columns[4]: 'most_influential_educators',
                   df.columns[5]: 'most_influential_pln',
                   df.columns[6]: 'most_influential_students',
                   df.columns[7]: 'most_influential_parents',
                   df.columns[8]: 'most_influential_others',

                   df.columns[9]: 'q5_None',
                   df.columns[10]: 'q5_AASL',
                   df.columns[11]: 'q5_ALA',
                   df.columns[12]: 'q5_state_library_assco',
                   df.columns[13]: 'q5_state_school_library_assco',
                   df.columns[14]: 'q5_state_library',
                   df.columns[15]: 'q5_state_Dept_education',
                   df.columns[16]: 'q5_ISTE',
                   df.columns[17]: 'q5_future_ready_schools',
                   df.columns[18]: 'q5_CCSS',
                   df.columns[19]: 'q5_NCTE',
                   df.columns[20]: 'q5_NCTM',
                   df.columns[21]: 'q5_NCSS',
                   df.columns[22]: 'q5_NGSS',
                   df.columns[23]: 'q5_CAEP',
                   df.columns[24]: 'q5_NBPTS',
                   df.columns[25]: 'q5_CoSN',
                   df.columns[26]: 'q5_others',

                   df.columns[27]: 'AASL_member', # Q6
                   df.columns[28]: 'aware_revision', # Q8
                   df.columns[29]: 'purchase', # Q9
                   df.columns[30]: 'q10_currently_use', # Q10
                   df.columns[31]: 'q10_others',

                   # Q11
                   df.columns[32]: 'reason_not_use_school',
                   df.columns[33]: 'reason_not_use_state',
                   df.columns[34]: 'reason_not_use_accessible',
                   df.columns[35]: 'reason_not_use_prior_exp',
                   df.columns[36]: 'reason_not_use_broken_down',
                   df.columns[37]: 'reason_not_use_others'}
                   , inplace=True)

# %%
df.rename(columns={df.columns[38]: 'access_own', # Q12
                   df.columns[39]: 'access_borrow',
                   df.columns[40]: 'access_school',
                   df.columns[41]: 'access_plan_purchase',
                   df.columns[42]: 'access_framework_web',
                   df.columns[43]: 'access_framework_poster',
                   df.columns[44]: 'access_others',

                   df.columns[45]: 'familarity', # Q13
                   df.columns[46]: 'overall_rating', # Q14
                   df.columns[47]: 'poor_rating_reasons', # Q15

                   # Q16 - higher score, higher rating
                   df.columns[48]: 'book_valuable',
                   df.columns[49]: 'book_relevant',
                   df.columns[50]: 'book_practical',
                   df.columns[51]: 'book_useful',
                   df.columns[52]: 'book_easy_to_use',
                   df.columns[53]: 'book_easy_to_understand',
                   df.columns[54]: 'book_well_written',
                   df.columns[55]: 'book_nicely_designed',
                   df.columns[56]: 'book_well_organized',
                   df.columns[57]: 'book_ADA_accessible',


                   df.columns[58]: 'What you like about the book', # Q17
                   df.columns[59]: 'What you dislike about the book', # Q18

                   # Q19 - higher score, higher rating
                   df.columns[60]: 'standards_easy_to_explain',
                   df.columns[61]: 'standards_achievable',
                   df.columns[62]: 'standards_good_advocacy_tool',
                   df.columns[63]: 'standards_helps_foster_culture_changes',
                   df.columns[64]: 'standards_useful_for_collaboration',
                   df.columns[65]: 'standards_easy_to_implement',

                   # Q20
                   df.columns[66]: 'The AASL Standards are valuable to the library community.',
                   df.columns[67]: 'The AASL Standards are valuable to the education community.',
                   df.columns[68]: 'A good school librarian uses formal standards to develop and administer a school library.',
                   df.columns[69]: 'My school administration knows about the AASL Standards.',
                   df.columns[70]: 'The educators I collaborate with know about the AASL Standards.',
                   df.columns[71]: 'The AASL Standards reinforces the professionalism of school librarians.',
                   
                   # Q21
                   df.columns[72]: 'The school library is a unique and essential part of a learning community.',
                   df.columns[73]: 'Qualified school librarians lead effective school libraries',
                   df.columns[74]: 'Learners should be prepared for college, career and life.',
                   df.columns[75]: 'Reading is the core of personal and academic competency.',
                   df.columns[76]: "Intellectual freedom is every learner's right",
                   df.columns[77]: 'Information technologies must be appropriately integrated and equitably available.'}
                   , inplace=True)

# %%
df.rename(columns={df.columns[78]: 'use_frequency', # Q22
                   
                   # Q23
                   df.columns[79]: 'p1_Common Beliefs central to the profession.',
                   df.columns[80]: 'p1_Separate frameworks for Learners, School librarians, and School Libraries.',
                   df.columns[81]: 'p1_Competencies for Learners.',
                   df.columns[82]: 'p1_Competencies for School Librarians.',
                   df.columns[83]: 'p1_Alignments for School Libraries.',
                   df.columns[84]: 'p2_Integrated Frameworks by Shared Foundation [Inquire, Include, Collaborate, Curate, Explore, Engage]',
                   df.columns[85]: 'p2_Framework Competencies and Alignments in Depth.',
                   df.columns[86]: 'p2_Framework Best Practices.',
                   df.columns[87]: 'p3_Questions for the Reflective Practitioner at the end of each chapter.',
                   df.columns[88]: 'p3_chap12',
                   df.columns[89]: 'p3_chap13_Measuring School Librarian Growth Examples of aligning AAS: Standards with commonly used educator evaluation models.',
                   df.columns[90]: 'p3_chap13_Measuring School Librarian Growth Discussion on developing and measuring school librarian development growth plans.',
                   df.columns[91]: 'p3_chap14_Evaluating School Libraries Discussion of responsibilities at the school, district, and state level.',
                   df.columns[92]: 'p3_chap14_Evaluating School Libraries School Library Evaluation Checklist.',
                   df.columns[93]: 'p4_Scenarios for Professional Learning',
                   df.columns[94]: 'a_Useful Verbs',
                   df.columns[95]: 'a_Works Cited',
                   df.columns[96]: 'a_Suggested Further Reading',
                   df.columns[97]: 'a_Index',
                   df.columns[98]: 'a_Lists of Illustrations',

                   # Q24
                   df.columns[99]: 'The language of competency-based standards (p.19)',
                   df.columns[100]: 'The structure of the AASL Standards Frameworks (p.17)',
                   df.columns[101]: 'The interdependent nature of the learner, school librarian, and school library frameworks',
                   df.columns[102]: 'The Key Commitments of the Shared Foundatiions',
                   df.columns[103]: 'The interrelated aspects of the Shared Foundations',
                   df.columns[104]: 'The continuum of the learning Domains (p.15)',
                   df.columns[105]: 'The context of the Competencies and Alignments, explored in depth following each Shared Foundation framework',

                   # Q25
                   df.columns[106]: 'frequency_AASL Standards Frameworks_for Learners',
                   df.columns[107]: 'frequency_AASL Standards Frameworks_for School librarians',
                   df.columns[108]: 'frequency_AASL Standards Frameworks_for School Libraries',
                   
                   # Q26
                   df.columns[109]: 'frequency_shared foundations_Inquire',
                   df.columns[110]: 'frequency_shared foundations_Include',
                   df.columns[111]: 'frequency_shared foundations_collaborate',
                   df.columns[112]: 'frequency_shared foundations_curate',
                   df.columns[113]: 'frequency_shared foundations_explore',
                   df.columns[114]: 'frequency_shared foundations_engage',

                   # Q27
                   df.columns[115]: 'frequency_standards_Think',
                   df.columns[116]: "frequency_standards_Create",
                   df.columns[117]: 'frequency_Share',
                   df.columns[118]: 'frequency_Grow'}
                   , inplace=True)

# %%
df.rename(columns={df.columns[119]: 'lesson preparation and assessment', # Q28
                   df.columns[120]: 'School librarian evaluation',
                   df.columns[121]: 'Engaging with pther educators (school librarians, classroom teachers, administrators)',
                   df.columns[122]: 'Engaging with other libraries (community college, academic, public)',
                   df.columns[123]: 'Demonstrating success to others',
                   df.columns[124]: 'Guiding instructional priorities',
                   df.columns[125]: 'Developing school library curriculum',
                   df.columns[126]: 'Shaping the school library',
                   df.columns[127]: 'Making sure the school library is meeting national standards',
                   df.columns[128]: 'Advocating on behalf of the school library',
                   df.columns[129]: 'Advocating on behalf of the learners',
                   df.columns[130]: 'Increasing the understanding of the role of the school librarian',
                   df.columns[131]: 'Legitimizing the school librarian profession',
                   df.columns[132]: 'helpful_others',

                   df.columns[133]: 'suggestion_anything new', # Q29
                   
                   df.columns[134]: 'how do you use', # Q30

                   # Q31 Biggest challenges
                   df.columns[135]: 'Understanding how to implement the standards',
                   df.columns[136]: 'Understanding how to adapt standards to local curriculum',
                   df.columns[137]: 'Translating standards into lesson plans',
                   df.columns[138]: 'Understanding how to measure success for learners',
                   df.columns[139]: 'Understanding how to measure success for school librarians',
                   df.columns[140]: 'Understanding how to measure success for school libraries',
                   df.columns[141]: 'Accessing the standards',
                   df.columns[142]: 'Demonstrating alignment to content-area standards',
                   df.columns[143]: 'Lack of support from others',
                   df.columns[144]: 'Lack of time to invest to study the standards',
                   df.columns[145]: 'Lack of time for collaboration',
                   df.columns[146]: 'Lack of funding',
                   df.columns[147]: 'biggest_challanges_others',
                   
                   # Q32
                   df.columns[148]: 'Invest time to study and implement the standards',
                   df.columns[149]: 'Teach the standards to other school librarians',
                   df.columns[150]: 'Advocate the importance of school library standards',
                   df.columns[151]: 'Feature the standards in regular school and district reports',
                   df.columns[152]: 'Adapt existing lesson plans to incorporate the standards',
                   df.columns[153]: 'Collaborae with other educators on new lesson plans and instruction',
                   df.columns[154]: 'Develop tools that align with or integrate the standards',
                   df.columns[155]: 'Attend professional learning opportunities',
                   df.columns[156]: 'Collaborate with stakeholders to develop custom curriculum',
                   df.columns[157]: "overcome challenges_others"}
                   , inplace=True)

# %%
df.rename(columns={df.columns[158]: 'Knowledge Quest', # Q33
                   df.columns[159]: 'AASL National Conference',
                   df.columns[160]: 'AASL e-Learning',
                   df.columns[161]: 'AASL Publications',
                   df.columns[162]: 'School district training',
                   df.columns[163]: 'State association training',
                   df.columns[164]: 'Self-directed training',
                   df.columns[165]: 'Expand personal learning by leading local, state, or national trainings for others',
                   df.columns[166]: 'Attend workshops at the local, state, or national level',
                   df.columns[167]: 'Attend webinars and online learning events',
                   df.columns[168]: 'Access my personal learning networks',
                   df.columns[169]: 'Access my social media networks',
                   df.columns[170]: 'receive_others',
                   
                   df.columns[171]: 'rating_AASL initiative and efforts', # Q34

                   df.columns[172]: 'rating_reasoning', # Q35
                   
                   df.columns[173]: 'additional_useful_supports', # Q36

                   df.columns[174]: 'anything_to_add'} # Q50
                   , inplace=True)

# %% [markdown]
# We have now fixed all the fields' names. Now it's time to drop the first row and reset the index.

# %%
df = df.iloc[1:].reset_index(drop=True)

# %%
df.head()
# Out:
#                                  jobRole most_influential_school_board  \
# 0  Certified / licensed school librarian                             6
# 1  Certified / licensed school librarian                             8
# 2  Certified / licensed school librarian                             7
# 3  Certified / licensed school librarian                             4
# 4  Certified / licensed school librarian                             4
#
#   most_influential_school_administrator most_influential_school_principal  \
# 0                                     5                                 3
# 1                                     6                                 7
# 2                                     5                                 4
# 3                                     6                                 1
# 4                                     6                                 3
#
#   most_influential_educators most_influential_pln most_influential_students  \
# ...

# %% [markdown]
# - **Handling null and missing data.**
# - **rescaling the questions that ask "rating something one a scale of what".**
#     To ensure consistency in analysis, we standardized all rating scales so that higher values always indicate more favorable responses. Previously, some questions used reversed or inconsistent scales, making comparisons difficult. For questions using "Strongly Agree", "Somewhat Agree", "Somewhat Disagree", and "Strongly Disagree", responses were mapped to numerical values for easier analysis. SImilarly, for ranking-based questions (e.g. "most influential" to "least influential"), we adjusted the scale so that higher scores consistently reflect more desirable outcomes.

# %%
# Q4 - 8: most influential, 1: least influential
# df.iloc[:, 1:9] = 9 - df.iloc[:, 1:9]

# # OneHot encode
# df.iloc[:, 9:26] = df.iloc[:, 9:26].notna().astype(int) # Q5
# df.iloc[:, 32:37] = df.iloc[:, 32:37].notna().astype(int) # Q11
# df.iloc[:, 38:44] = df.iloc[:, 38:44].notna().astype(int) # Q12

# # Replace extreme values with corresponding integers
# df.iloc[:, 48:58] = df.iloc[48:58].replace(
#     {
#         'Describes completely': 6,
#         'Does not describe at all': 0
#     }
# ).astype(int) # Q16

# df.iloc[:, 60:66] = df.iloc[60:66].replace(
#     {
#         'Describes completely': 6,
#         'Does not describe at all': 0
#     }
# ).astype(int) # Q19

# # Two-extremes rescale
# df.iloc[:, 66:78] = df.iloc[:, 66-78].replace({
#     "Strongly agree": 2,
#     "Somewhat agree": 1,
#     "Somewhat disagree": -1,
#     "Strongly disagree": -2
# }).astype(int) # Q20, Q21

# %% [markdown]
# #### Utilization

# %% [markdown]
# #### Strength

# %% [markdown]
# #### Challenges

# %% [markdown]
# #### Suggestions
